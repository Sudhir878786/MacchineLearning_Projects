# %% [markdown]
# ###Importing libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Importing dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset = pd.read_csv('./drive/MyDrive/Sentiment_Predictor/Copy of a1_RestaurantReviews_HistoricDump.tsv', delimiter = '\t', quoting = 3)

# %%
dataset.shape
# Out:
# (900, 2)

# %%
dataset.head()
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %% [markdown]
# ### Data cleaning

# %%
import re
import nltk

nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

all_stopwords = stopwords.words('english')
all_stopwords.remove('not')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus=[]

for i in range(0, 900):
  review = re.sub('[^a-zA-Z]', ' ', dataset['Review'][i])
  review = review.lower()
  review = review.split()
  review = [ps.stem(word) for word in review if not word in set(all_stopwords)]
  review = ' '.join(review)
  corpus.append(review)

# %%
corpus
# Out:
# ['wow love place',
#  'crust not good',
#  'not tasti textur nasti',
#  'stop late may bank holiday rick steve recommend love',
#  'select menu great price',
#  'get angri want damn pho',
#  'honeslti tast fresh',
#  'potato like rubber could tell made ahead time kept warmer',
#  'fri great',
#  'great touch',
#  'servic prompt',
#  'would not go back',
#  'cashier care ever say still end wayyy overpr',
#  'tri cape cod ravoli chicken cranberri mmmm',
#  'disgust pretti sure human hair',
#  'shock sign indic cash',
#  'highli recommend',
#  'waitress littl slow servic',
#  'place not worth time let alon vega',
#  'not like',
#  'burritto blah',
#  'food amaz',
#  'servic also cute',
#  'could care less interior beauti',
#  'perform',
#  'right red velvet cake ohhh stuff good',
#  'never brought salad ask',
#  'hole wall great mexican street taco friendli staff',
#  'took hour get food tabl restaur food luke warm sever run around like total overwhelm',
#  'worst salmon sashimi',
# ...

# %% [markdown]
# ### Data transformation

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 1420)

# %%
X = cv.fit_transform(corpus).toarray()
y = dataset.iloc[:, -1].values

# %%
# Saving BoW dictionary to later use in prediction
import pickle
bow_path = './drive/MyDrive/Sentiment_Predictor/Copy of c1_BoW_Sentiment_Model.pkl'
pickle.dump(cv, open(bow_path, "wb"))

# %% [markdown]
# ### Dividing dataset into training and test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %% [markdown]
# ### Model fitting (Naive Bayes)

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# Exporting NB Classifier to later use in prediction
import joblib
joblib.dump(classifier, './drive/MyDrive/Sentiment_Predictor/Copy of c2_Classifier_Sentiment_Model')
# Out:
# ['./drive/MyDrive/Sentiment_Predictor/Copy of c2_Classifier_Sentiment_Model']

# %% [markdown]
# ###Model performance

# %%
y_pred = classifier.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)

accuracy_score(y_test, y_pred)
# Out:
# [[67 11]
#  [38 64]]
# 0.7277777777777777
